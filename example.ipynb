# %% [markdown]
# # RL Portfolio Optimization Example
#
# This notebook demonstrates how to use the refactored RL pipeline.

# %%
# Install dependencies if needed
# !pip install stable-baselines3 gym pandas numpy matplotlib stockstats shap

# %%
# Train a PPO model
# !python train.py --algo PPO --timesteps 1000 --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx

# %%
# Validate the model
# !python validate.py --algo PPO --seed 42

# %%
# Backtest the model
# !python backtest.py --algo PPO --seed 42

# %%
# Run full pipeline
# !python run.py --algo PPO --timesteps 1000 --seed 42
