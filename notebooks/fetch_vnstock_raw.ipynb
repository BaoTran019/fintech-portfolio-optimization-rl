# %%
# %run ../utils/fetch_vnstock_raw.py --symbols MWG BID VCB VIC MBB --output test_data.xlsx
# Out:
# --- Begin to get data from 2015-01-01 to 2025-12-31 ---
# Processing MWG...
# Processing BID...
# Processing VCB...
# Processing VIC...
# Processing MBB...
#
# Getting data successful: Saved 13740 lines into ../dataset\test_data.xlsx
