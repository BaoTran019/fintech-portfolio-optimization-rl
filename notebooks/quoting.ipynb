# %%
from vnstock import Listing, Quote
# Out:
# c:\Users\BAORTG\AppData\Local\Programs\Python\Python312\Lib\site-packages\vnai\scope\profile.py:562: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Phiên bản Vnstock 3.4.2 đã có mặt, vui lòng cập nhật với câu lệnh : `pip install vnstock --upgrade`.
# Lịch sử phiên bản: https://vnstocks.com/docs/tai-lieu/lich-su-phien-ban
# Phiên bản hiện tại 3.2.6
# Phiên bản Vnai 2.3.9 đã có mặt, vui lòng cập nhật với câu lệnh : `pip install vnai --upgrade`.
# Lịch sử phiên bản: https://pypi.org/project/vnai/#history
# Phiên bản hiện tại 2.1.9

# %%
VNINDEX_quote = Quote(symbol='VNINDEX', source='VCI')

# %%
START_DATE = '2015-01-01'
END_DATE = '2025-12-31'

# %%
VNINDEX_quote.history(start = START_DATE, end = END_DATE, interval='1D')
# Out:
#            time     open     high      low    close      volume
# 0    2015-01-05   544.86   549.22   543.78   544.45    91834620
# 1    2015-01-06   539.08   550.11   538.82   549.66    94081890
# 2    2015-01-07   548.44   555.83   548.44   552.05   109445780
# 3    2015-01-08   553.49   556.80   552.15   553.47    73883040
# 4    2015-01-09   553.49   570.52   552.15   569.73   104203680
# ...         ...      ...      ...      ...      ...         ...
# 2743 2025-12-25  1779.19  1805.93  1742.85  1742.85   830259375
# 2744 2025-12-26  1706.39  1730.99  1687.14  1729.80  1081379964
# 2745 2025-12-29  1733.39  1754.84  1731.63  1754.84   681132121
# 2746 2025-12-30  1758.45  1766.90  1740.07  1766.90   639630103
# 2747 2025-12-31  1760.81  1787.75  1760.14  1784.49   704538818
#
# [2748 rows x 6 columns]
