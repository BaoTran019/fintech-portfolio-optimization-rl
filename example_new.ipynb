# %%
for file in sorted([f for f in os.listdir('results/plots/') if 'shap' in f.lower()])[:6]:
    img = Image.open(f'results/plots/{file}')
    plt.figure(figsize=(14, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title(file, fontsize=10)
    plt.show()

# %% [markdown]
# ## SHAP Explanations

# %%
img = Image.open(f'results/{algo.lower()}_seed_{seed}_account_value_comparison.png')
plt.figure(figsize=(12, 6))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Account Value Comparison

# %%
img = Image.open(f'results/{algo.lower()}_seed_{seed}_distribution.png')
plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Stock Distribution

# %%
img = Image.open(f'results/{algo.lower()}_seed_{seed}_cumulative_return_comparison.png')
plt.figure(figsize=(12, 6))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Cumulative Returns

# %%
pd.read_csv(f'results/metrics/{algo.lower()}_seed_{seed}_metrics.csv')

# %% [markdown]
# ## Metrics

# %%
img = Image.open(f'results/plots/{algo.lower()}_loss_seed_{seed}.png')
plt.figure(figsize=(12, 6))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Training Loss

# %%
# !python train.py --algo PPO --timesteps 5000 --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx
# !python backtest.py --algo PPO --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx
# !python explain.py --algo PPO --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx --n_samples 100

# %% [markdown]
# ## Step 1: Train & Backtest

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

plt.style.use('seaborn-v0_8-darkgrid')

algo = 'PPO'
seed = 42

# %% [markdown]
# # RL Portfolio Optimization - Results Dashboard
