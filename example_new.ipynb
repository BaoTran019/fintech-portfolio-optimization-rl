# %% [markdown]
# # RL Portfolio Optimization Example
#
# This notebook demonstrates how to use the refactored RL pipeline.

# %%
# Install dependencies if needed
# !pip install stable-baselines3 gym pandas numpy matplotlib stockstats shap finrl

# %%
# Train a PPO model
# !python train.py --algo PPO --timesteps 1000 --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx

# %%
# Validate the model
# !python validate.py --algo PPO --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx

# %%
# Backtest the model
# !python backtest.py --algo PPO --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx

# %% [markdown]
# ## SHAP Model Explanation
#
# After training, you can explain the model's decisions using SHAP analysis.

# %%
# Explain the trained PPO model
# !python explain.py --algo PPO --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx --n_samples 50

# %% [markdown]
# ## Run Full Pipeline
#
# Run the complete pipeline (train, validate, backtest) in one command.

# %%
# Run full pipeline
# !python run.py --algo PPO --timesteps 1000 --seed 42 --data_path dataset/5_vn30_vnsi_symbols_data.xlsx --vnindex_path dataset/vnindex.xlsx

# %% [markdown]
# ## View Generated Results
#
# Check the results directory for generated files.

# %%
# List generated models
# !ls results/models/

# %%
# List loss plots
# !ls results/plots/

# %%
# List SHAP plots
# !ls results/plots/ | grep shap
